# %% [markdown]
# <a href="https://colab.research.google.com/github/Crall-Lab/SICB2025_CV/blob/main/deepLearningNotebooks/1_training/iNat_SICB_CNN_transferLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!
#
# For this exercise we will be using transfer learning to train a model on a dataset that we create from images grabbed from the internet
#
#
#
# *   To execute a tab, click on the left side of the tab (where a play button
# *   Double click a tab to show the code
# *   Feel free to explore and change things!

# %%
# clone the SICB Computer Vision Github
# !git clone https://github.com/Crall-Lab/SICB2025_CV.git
# Out:
# Cloning into 'SICB2025_CV'...
# remote: Enumerating objects: 478, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 478 (delta 41), reused 14 (delta 14), pack-reused 398 (from 2)
# Receiving objects: 100% (478/478), 470.23 MiB | 29.36 MiB/s, done.
# Resolving deltas: 100% (216/216), done.
# Updating files: 100% (47/47), done.

# %%
#@title import python libraries
from matplotlib import pyplot as plt
import glob
import cv2 as cv
import numpy as np
import os

#from tflite_model_maker.config import ExportFormat
#from tflite_model_maker import model_spec
#from tflite_model_maker import object_detector
#from  tflite_model_maker import image_classifier
from bing_image_downloader import downloader

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
import tensorflow.keras.layers as tfl
#from tensorflow.keras.preprocessing import image_dataset_from_directory
#from tensorflow.keras.layers.preprocessing import RandomFlip, RandomRotation

# %% [markdown]
# # Create your dataset

# %%
#@title Unzip all files
# !unzip /content/SICB2025_CV/deepLearningNotebooks/1_training/trainIms0.zip
# !unzip /content/SICB2025_CV/deepLearningNotebooks/1_training/trainIms1.zip
# !unzip /content/SICB2025_CV/deepLearningNotebooks/1_training/trainIms2.zip
# !unzip /content/SICB2025_CV/deepLearningNotebooks/1_training/trainIms3.zip
# !unzip /content/SICB2025_CV/deepLearningNotebooks/1_training/trainIms4.zip
# !unzip /content/SICB2025_CV/deepLearningNotebooks/1_training/trainIms5.zip

# !unzip /content/SICB2025_CV/deepLearningNotebooks/1_training/valIms1.zip
# !unzip /content/SICB2025_CV/deepLearningNotebooks/1_training/valIms2.zip

# %%
#@title Move images to a single folder
import glob
import os
import shutil

# For the training files
getFolds = glob.glob('/content/content/train_*/*')
for ele in getFolds:
  if os.path.isdir('/content/trainIms/'+ele.split('/')[-1]) == False:os.makedirs('/content/trainIms/'+ele.split('/')[-1])


getFiles = glob.glob('/content/content/train_*/*/*')
for ele in getFiles:
  tempFile = '/content/trainIms/'+ele.split('/')[-2]+'/'+ele.split('/')[-1]
  shutil.copyfile(ele,tempFile)



# for the validation files
getFolds = glob.glob('/content/content/valIm*/*')
for ele in getFolds:
  if os.path.isdir('/content/valIms/'+ele.split('/')[-1]) == False:os.makedirs('/content/valIms/'+ele.split('/')[-1])


getFiles = glob.glob('/content/content/valIm*/*/*')
for ele in getFiles:
  tempFile = '/content/valIms/'+ele.split('/')[-2]+'/'+ele.split('/')[-1]
  shutil.copyfile(ele,tempFile)

# !rm /content/content/ -r

# %% [markdown]
# # Preparing your dataset
#
# We'll use tensorflow tools to automatically prepare your dataset based off the directory path, '/content/dataset/, and all the subdirectories within.
#
# By default we'll split the dataset into 85% training data andd 15% validation data (feel free to update)
#
#
#
# *   If any GIFs made it into your dataset, be sure to delete them

# %%
from pathlib import Path
import imghdr

data_dir = "/content/trainIms/"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            os.remove(filepath)

# %%
BATCH_SIZE = 32
IMG_SIZE = (160, 160)
directory = "/content/trainIms/"
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(directory,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.2,
                                             subset='training',
                                             seed=42)
validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(directory,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.2,
                                             subset='validation',
                                             seed=42)
# Out:
# Found 432 files belonging to 18 classes.
# Using 346 files for training.
# Found 432 files belonging to 18 classes.
# Using 86 files for validation.

# %%
label_list = train_dataset.class_names
out1 = open('/content/labels.txt','w')
labelKey = {}
for ind1,ele in enumerate(label_list):
  if ind1 == len(label_list)-1:
    out1.write('%s %s'%(ind1,ele))
  else:
    out1.write('%s %s \n'%(ind1,ele))
  labelKey[ind1] = ele
out1.close()

# %% [markdown]
# # TRAIN YOUR MODEL
#
# in the next few lines of code we will use transfer learning on a pretrained mobilenet-V2 model using the training set and validation set that you created!

# %%
IMG_SIZE = (160,160)
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=True,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160.h5
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(6, 6))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
nb_layers = len(base_model.layers)
print(base_model.layers[nb_layers - 2].name)
print(base_model.layers[nb_layers - 1].name)
# Out:
# global_average_pooling2d_5
# predictions

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 1000)

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
# GRADED FUNCTION: data_augmenter
def data_augmenter():
    '''
    Create a Sequential model composed of 2 layers
    Returns:
        tf.keras.Sequential
    '''
    # data_augmentation = None
    # data_augmentation.add(None)
    # data_augmentation.add(None)
    # YOUR CODE STARTS HERE
    data_augmentation = tf.keras.Sequential([
  tfl.RandomFlip("horizontal"),
  tfl.RandomRotation(0.2),
])
    # YOUR CODE ENDS HERE

    return data_augmentation

# %%
# GRADED FUNCTION
def sicb_model(image_shape=IMG_SIZE, data_augmentation=data_augmenter()):
    ''' Define a tf.keras model for binary classification out of the MobileNetV2 model
    Arguments:
        image_shape -- Image width and height
        data_augmentation -- data augmentation function
    Returns:
    Returns:
        tf.keras.model
    '''


    input_shape = image_shape + (3,)

    # base_model = tf.keras.applications.MobileNetV2(input_shape=None,
    #                                               include_top=False, # <== Important!!!!
    #                                               weights=imagenet) # From imageNet

    # Freeze the base model by making it non trainable
    # base_model.trainable = None

    # create the input layer (Same as the imageNetv2 input size)
    # inputs = tf.keras.Input(shape=None)

    # apply data augmentation to the inputs
    # x = None

    # data preprocessing using the same weights the model was trained on
    # x = preprocess_input(None)

    # set training to False to avoid keeping track of statistics in the batch norm layer
    # x = base_model(None, training=None)

    # Add the new Binary classification layers
    # use global avg pooling to summarize the info in each channel
    # x = None()(x)
    #include dropout with probability of 0.2 to avoid overfitting
    # x = None(None)(x)

    # create a prediction layer with one neuron (as a classifier only needs one)
    # prediction_layer = None

    # YOUR CODE STARTS HERE

    base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
    base_model.trainable = False
    inputs = tf.keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(x)
    x = base_model(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tfl.Dropout(.2)(x)
    prediction_layer = tf.keras.layers.Dense(3)
    # YOUR CODE ENDS HERE

    outputs = prediction_layer(x)
    outputs2 = tf.keras.activations.softmax(outputs)
    model = tf.keras.Model(inputs, outputs2)

    return model

# %%
data_augmentation = data_augmenter()

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
model2 = sicb_model(IMG_SIZE, data_augmentation)

# %%
base_learning_rate = 0.01
model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy,
              metrics=['accuracy'])

# %%
initial_epochs = 5
history = model2.fit(train_dataset, validation_data=validation_dataset, epochs=initial_epochs)
# Out:
# Epoch 1/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4025 - loss: 2.0512 - val_accuracy: 0.3514 - val_loss: 2.0665
# Epoch 2/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.7214 - loss: 0.9494 - val_accuracy: 0.6486 - val_loss: 1.3825
# Epoch 3/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7992 - loss: 0.6299 - val_accuracy: 0.5946 - val_loss: 1.3807
# Epoch 4/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 919ms/step - accuracy: 0.8880 - loss: 0.2977 - val_accuracy: 0.6757 - val_loss: 1.3410
# Epoch 5/5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8907 - loss: 0.2223 - val_accuracy: 0.5946 - val_loss: 1.2247

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = model2(image_batch)
print(feature_batch.shape)
# Out:
# (32, 3)

# %%
plt.imshow(image_batch[1,:,:,:].cpu()/255)

# %%
in1 = cv.imread('/content/scissors.jpg')
in2 = np.expand_dims(cv.resize(in1,(160,160)),0)
out1 = model2.predict(in2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
test = cv.imread('/content/scissors.jpg')[:,:,::-1]
ax = plt.subplot(1,2,1)
test = cv.resize(test,(224,224))
ax.imshow(test)
ax = plt.subplot(1,2,2)
ax.imshow(test)

indy = np.argsort(np.squeeze(out1))[::-1]
conf_final = np.array(np.squeeze(out1))[indy]
lbls_final = [labelKey[ele] for ele in indy]

cnt = 0
for conf1,lbls1 in zip(conf_final,lbls_final):
  conf = np.round(conf1,2)
  plt.text(25,25+(15*cnt),'%s: %s'%(conf,lbls1),color=(1,0,0))
  cnt+=1

# %%
model2.export("/content/model_rps/")
# Out:
# Saved artifact at '/content/model_rps/'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='keras_tensor_1110')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   140050426667856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050426666624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050426223904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535940688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535950720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535951776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535944032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535945440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535941216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535953536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535942272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535941744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535947376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535930464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535931520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535926064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535930288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535936272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535935216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535937680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535933808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535936448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050535934160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536173584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536176224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536172176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536174112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536182384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536181328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536183792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536170240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536182560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536179568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536238240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536235776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536237888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536238416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536245280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536244224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536246864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536235072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536244752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536249856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536322272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536323680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536317872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536320160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536327728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050426486928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536327376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536328960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536399264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536250912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536409472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536411232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536405600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536410000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536414224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050433527824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050432674976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536500208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536500032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536404544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546363552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546369536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546371648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546371472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546373584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546362320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546360912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546361264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548361168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546360384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548359760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548364864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548368560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548359936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548366448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548369616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548367328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548373664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548367680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548372080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548074176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548070480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548067840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548076112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548078576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548077520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548064848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548073824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548078752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546367424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547846032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547841104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547837408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547844800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547849728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547843040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547835296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547849904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547846736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547835648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546792880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546787952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546794464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546792000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546795168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546798160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546796752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546788304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547402608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546790416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547405600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547401376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547398560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547408064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547393984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547403664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547395040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547396976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547392752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050547843920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549388064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549375392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549381200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549389120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549390176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549384544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549382608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549381904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549389648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549377328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549155520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549157808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549152176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549156400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549155696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549147600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549161504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549153936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549155872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549154112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546626752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546635728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546634848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546630624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546627104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546624816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546624112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546636960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546623056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549385600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548889328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548897072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548887744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548888800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548885808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548896544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548899184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548884576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548886160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548898304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546553456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546550112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546555568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546549936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546552048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546554160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546551872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546551344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549901792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050546553280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549900912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549907248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549911472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549908304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549913056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549904784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549908480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549910944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549909888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548897248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548630000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548631056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548628416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548630528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548622080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548637040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548622960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548634048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548635456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050548623312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550086592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550079728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550085008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550087648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550091696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550095040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550093808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550095392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550093984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550086944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550183840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550185776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550177856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550181024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550187184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550183136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550189824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550179616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550191760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550190528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550290768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550289888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550287248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550289536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550283376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550276512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550281792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550288304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550279680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050550290064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551333536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551326672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551328960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551324912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551333184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551328608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551340576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551332304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551339168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551336880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549520896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549509632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549510512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549521072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549518784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549509104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549516144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549520368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050549513152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551743136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551738384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551742784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551748768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551735216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551740144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551747184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551746128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551735568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551735920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551743488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551785424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551799152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050553499216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551337408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050551794576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050553499744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050553498512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050553496752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050536249328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140050552200128: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Convert the saved model using TFLiteConverter
converter = tf.lite.TFLiteConverter.from_saved_model('/content/model_rps/')
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # enable LiteRT ops.
    tf.lite.OpsSet.SELECT_TF_OPS  # enable TensorFlow ops.
]
tflite_model = converter.convert()

with open('model_rps.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
#@title Auth and import
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
import numpy as np
drive.mount('/content/drive',force_remount=True)

# %%
import shutil
shutil.copy('/content/model_rps/','/content/drive/MyDrive/sicb_iNat_model/')
